# %%
# install stable baselines
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /opt/conda/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (1.19.5)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: torch>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (1.10.1)
# Requirement already satisfied: gym<0.20,>=0.17 in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (0.18.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (3.4.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from stable-baselines3) (1.3.1)
# Requirement already satisfied: Pillow<=8.2.0 in /opt/conda/lib/python3.9/site-packages (from gym<0.20,>=0.17->stable-baselines3) (8.2.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from gym<0.20,>=0.17->stable-baselines3) (1.7.0)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from gym<0.20,>=0.17->stable-baselines3) (1.5.15)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch>=1.8.1->stable-baselines3) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->stable-baselines3) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->stable-baselines3) (2021.1)

# %%
# example from https://github.com/DLR-RM/stable-baselines3

import gym
from gym import wrappers
from stable_baselines3 import PPO

def vid(episode):
    return episode%20 == 0

env = gym.make("LunarLanderContinuous-v2")
env = wrappers.Monitor(env, "./gym-resultsPPO", force=True,video_callable = vid)

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    fps             | 710      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -182         |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041434336 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.00138      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 794          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00574     |
# |    std                  | 1.01         |
# |    value_loss           | 1.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -191         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0042979843 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.0123      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 335          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00561     |
# |    std                  | 1.02         |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -187         |
# | time/                   |              |
# |    fps                  | 553          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0060050515 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.0034      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 533          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00522     |
# |    std                  | 1.03         |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | -176         |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059307925 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | -0.0262      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00499     |
# |    std                  | 1.05         |
# |    value_loss           | 753          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006266193 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.000391   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00422    |
# |    std                  | 1.04        |
# |    value_loss           | 428         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008497058 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.00256    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 1.04        |
# |    value_loss           | 470         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 8           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009384768 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | -0.000373   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00823    |
# |    std                  | 1.03        |
# |    value_loss           | 242         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 9           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007997484 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -0.000498   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00712    |
# |    std                  | 1.03        |
# |    value_loss           | 251         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 10          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006727175 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -0.00105    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00854    |
# |    std                  | 1.03        |
# |    value_loss           | 328         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | -98.6        |
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 11           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031886527 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -0.000173    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00507     |
# |    std                  | 1.03         |
# |    value_loss           | 339          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 12          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008997024 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -2.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00865    |
# |    std                  | 1.04        |
# |    value_loss           | 322         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -72.4        |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 13           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0044158096 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.000108     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 230          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 1.03         |
# |    value_loss           | 384          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -66.4       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 14          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007598236 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | -0.000166   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00513    |
# |    std                  | 1.03        |
# |    value_loss           | 268         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -63.1        |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 15           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0066364408 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.000718     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 179          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00484     |
# |    std                  | 1.04         |
# |    value_loss           | 218          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | -58.9       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 16          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005760637 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.0886      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00616    |
# |    std                  | 1.04        |
# |    value_loss           | 182         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -53.3        |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 17           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0062794094 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 125          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00593     |
# |    std                  | 1.03         |
# |    value_loss           | 138          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | -50         |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 18          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005792426 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00637    |
# |    std                  | 1.02        |
# |    value_loss           | 185         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 19          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006622481 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00799    |
# |    std                  | 1.01        |
# |    value_loss           | 65          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | -42.7       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 20          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005764577 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00627    |
# |    std                  | 1.01        |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | -42.2       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 21          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006626743 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 1.01        |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -38.9       |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 22          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005873994 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00656    |
# |    std                  | 1           |
# |    value_loss           | 98          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | -37.7       |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 23          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007901252 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.993       |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | -33.4       |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 24          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006361694 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00613    |
# |    std                  | 0.979       |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -33.1       |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 25          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005616136 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.42        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00494    |
# |    std                  | 0.966       |
# |    value_loss           | 25.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | -31.7        |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 26           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0054110736 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00442     |
# |    std                  | 0.962        |
# |    value_loss           | 69.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 369          |
# |    ep_rew_mean          | -32.5        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 27           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0058971397 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 0.954        |
# |    value_loss           | 32.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | -32.2        |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 28           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0051346794 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00406     |
# |    std                  | 0.947        |
# |    value_loss           | 124          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | -34.6       |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 29          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009325538 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00631    |
# |    std                  | 0.94        |
# |    value_loss           | 72.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 418          |
# |    ep_rew_mean          | -35.9        |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 30           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0073767146 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00488     |
# |    std                  | 0.931        |
# |    value_loss           | 63.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | -37.3       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 31          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003704046 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00266    |
# |    std                  | 0.926       |
# |    value_loss           | 61          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 448        |
# |    ep_rew_mean          | -35        |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 32         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00625893 |
# |    clip_fraction        | 0.0605     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.2       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00655   |
# |    std                  | 0.915      |
# |    value_loss           | 30.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 465         |
# |    ep_rew_mean          | -37.1       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 33          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010601204 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.77        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 0.897       |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 481         |
# |    ep_rew_mean          | -35.4       |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 34          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004064496 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00381    |
# |    std                  | 0.896       |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 499          |
# |    ep_rew_mean          | -34.2        |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 35           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0077325087 |
# |    clip_fraction        | 0.0871       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.737        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00479     |
# |    std                  | 0.881        |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | -34.8        |
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 36           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039876513 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.41         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.875        |
# |    value_loss           | 16.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | -34.3       |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 37          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003950959 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00317    |
# |    std                  | 0.872       |
# |    value_loss           | 45.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 550          |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 38           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0066435505 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.95         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00621     |
# |    std                  | 0.851        |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -34.4       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 39          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004001573 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.46        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0025     |
# |    std                  | 0.837       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 581          |
# |    ep_rew_mean          | -34.3        |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 40           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0050694696 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.5         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.824        |
# |    value_loss           | 42           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | -31.5       |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 41          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008005457 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.05        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00383    |
# |    std                  | 0.824       |
# |    value_loss           | 12.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 620          |
# |    ep_rew_mean          | -30.1        |
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 42           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0066754483 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.64         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00378     |
# |    std                  | 0.822        |
# |    value_loss           | 65.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 628         |
# |    ep_rew_mean          | -28         |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 43          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008337067 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00409    |
# |    std                  | 0.802       |
# |    value_loss           | 7.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 641         |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 44          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007036491 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00263    |
# |    std                  | 0.794       |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 661          |
# |    ep_rew_mean          | -23.8        |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 45           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0048018023 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.789        |
# |    value_loss           | 92           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 678         |
# |    ep_rew_mean          | -24.1       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 46          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005338163 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00782    |
# |    std                  | 0.778       |
# |    value_loss           | 47          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 693          |
# |    ep_rew_mean          | -23.4        |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 47           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0070205317 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.61         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00287     |
# |    std                  | 0.774        |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 710          |
# |    ep_rew_mean          | -21.3        |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 48           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0054732086 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000244     |
# |    std                  | 0.765        |
# |    value_loss           | 43.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 721         |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 49          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010833181 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00686    |
# |    std                  | 0.769       |
# |    value_loss           | 10.4        |
# -----------------------------------------

# %%
# run the last episode until finish
obs, reward, done, info =  env.step([0,0])
while not done:
    obs, reward, done, info =  env.step([0,0])



# get them sweet renders
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()

# %%
# example from https://github.com/DLR-RM/stable-baselines3

from stable_baselines3 import TD3

def vid(episode):
    return episode%2 == 0

env = gym.make("LunarLanderContinuous-v2")
env = wrappers.Monitor(env, "./gym-resultsTD3", force=True,video_callable = vid)

model = TD3("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.2     |
# |    ep_rew_mean     | -491     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 69       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 353      |
# | train/             |          |
# |    actor_loss      | 5.77     |
# |    critic_loss     | 68       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 284      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.2     |
# |    ep_rew_mean     | -488     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 73       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 730      |
# | train/             |          |
# |    actor_loss      | 6.08     |
# |    critic_loss     | 116      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 648      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | -392     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 74       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2018     |
# | train/             |          |
# |    actor_loss      | 3.27     |
# |    critic_loss     | 39.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1911     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 165      |
# |    ep_rew_mean     | -392     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 76       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2644     |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 37       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2554     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63/86606156.py in <module>
#      10
#      11 model = TD3("MlpPolicy", env, verbose=1)
# ---> 12 model.learn(total_timesteps=100000)
#
# /opt/conda/lib/python3.9/site-packages/stable_baselines3/td3/td3.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     202     ) -> OffPolicyAlgorithm:
#     203
# --> 204         return super(TD3, self).learn(
#     205             total_timesteps=total_timesteps,
#     206             callback=callback,
#
# /opt/conda/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     369                 # Special case when the user passes `gradient_steps=0`
#     370                 if gradient_steps > 0:
# --> 371                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     372
#     373         callback.on_training_end()
#
# /opt/conda/lib/python3.9/site-packages/stable_baselines3/td3/td3.py in train(self, gradient_steps, batch_size)
#     154
#     155                 # Compute the next Q-values: min over all critics targets
# --> 156                 next_q_values = th.cat(self.critic_target(replay_data.next_observations, next_actions), dim=1)
#     157                 next_q_values, _ = th.min(next_q_values, dim=1, keepdim=True)
#     158                 target_q_values = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.9/site-packages/stable_baselines3/common/policies.py in forward(self, obs, actions)
#     882             features = self.extract_features(obs)
#     883         qvalue_input = th.cat([features, actions], dim=1)
# --> 884         return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#     885
#     886     def q1_forward(self, obs: th.Tensor, actions: th.Tensor) -> th.Tensor:
#
# /opt/conda/lib/python3.9/site-packages/stable_baselines3/common/policies.py in <genexpr>(.0)
#     882             features = self.extract_features(obs)
#     883         qvalue_input = th.cat([features, actions], dim=1)
# --> 884         return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#     885
#     886     def q1_forward(self, obs: th.Tensor, actions: th.Tensor) -> th.Tensor:
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /opt/conda/lib/python3.9/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %%
vid = wrappers.record_episode_statistics(env=env,path="vid.mp4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_63/1788701071.py in <module>
# ----> 1 vid = wrappers.record_episode_statistics(env=env,path="vid.mp4")
#
# TypeError: 'module' object is not callable
